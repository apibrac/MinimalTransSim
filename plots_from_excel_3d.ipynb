# %%
'''3D plots
can be used to visualize general results when two parameter change (Vector Mode)
'''
# Out:
# '3D plots\ncan be used to visualize general results when two parameter change (Vector Mode)\n'

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#READ DATA
file_position="data/example/2016166165724_general.csv"

with open(file_position , "r") as file :
    content=file.read()
    print("succeed")
data=content.split("\n")
legend=data[0].split(",")
del data[0]
for i,li in enumerate(legend):
    print(i," : ",li)
# Out:
# succeed
# 0  :  id_sim
# 1  :  nb_passenger
# 2  :  nb_driver
# 3  :  execution_time
# 4  :  nb_match
# 5  :  driver_efficiency
# 6  :  passenger_efficiency
# 7  :  average_waiting_time
# 8  :  average_vks
# 9  :  total_vks
# 10  :  N_passenger
# 11  :  N_driver

# %%
#DECIDE WHAT TO PLOT
X=1
Y=2
Z=4

# %%
#PLOT

x,y,z=[],[],[]
for line in data:
    val=line.split(",")
    if len(val)>1:
        x.append(float(val[X]))
        y.append(float(val[Y]))
        z.append(float(val[Z]))
        
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(x,y,z)
ax.plot_trisurf(x,y,z)
ax.set_xlabel(legend[X])
ax.set_ylabel(legend[Y])
ax.set_zlabel(legend[Z])
# Out:
# <img src="data:image/png;base64,...">

# %%
#SAVE THE FIGURE
name=file_position[0:-4]+"_"+legend[Z]+"_VS_"+legend[X]+"_and_"+legend[Y]
plt.savefig(name)
