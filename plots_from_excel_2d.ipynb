# %%
#3D plots

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#READ DATA
file_position="data/2016126153221_passengers.csv"

with open(file_position , "r") as file :
    content=file.read()
    print("succeed")
data=content.split("\n")
legend=data[0].split(",")
del data[0]
for i,li in enumerate(legend):
    print(i," : ",li)
# Out:
# succeed
# 0  :  id_number
# 1  :  Ox
# 2  :  Oy
# 3  :  Dx
# 4  :  Dy
# 5  :  last_departure_time
# 6  :  matched
# 7  :  driver
# 8  :  waiting

# %%
#DECIDE WHAT TO PLOT
X=6
Y=12

# %%
#PLOT

x,y=[],[]
for line in data:
    val=line.split(",")
    if len(val)>1 and val[X] is not "" and val[Y] is not "":
        x.append(float(val[X]))
        y.append(float(val[Y]))
        
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(x,y)
ax.set_xlabel(legend[X])
ax.set_ylabel(legend[Y])
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.savefig('data/11_vks_f_vot')
